# %%
"""
STEPS:
1. Get list of video IDs in playlist from calling YT Data API v3 (playlistItems list)
2. Get video details and metadata from video ID list (videos list)
    > snippet (tags, published date, title, description)
    > statistics (comment, like, dislike, view counts)
3. Get publishedAt, user ID, video ID for comments on each video (commentThread list)
4. Convert publishedAt to timestamp
5. Use boto3 to import to S3
6. Use Glue to create schema in avro format
7. Create model with AWS Personalize
"""

# %%
import requests
import pandas as pd
import xlsxwriter
import openpyxl

api_key = '<API_KEY>'
playlist_id = 'PLvahqwMqN4M2N01FfQy2wXkyVyucAL86b'

# %%
def get_vid_list(playlist_id, token=''):
    videos = []
    while token or token=='':
        api_call = 'https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId={}&key={}'.format(playlist_id, api_key)
        if token:
            api_call+= '&pageToken={}'.format(token) 
        result = requests.get(api_call).json()
        videos += [item['contentDetails']['videoId'] for item in result['items']]
        try:
            token= result['nextPageToken']
        except:
            token = False
    return videos

videos = get_vid_list(playlist_id)


def get_vid_data(video_id):
    api_call = 'https://youtube.googleapis.com/youtube/v3/videos?part=snippet%2Cstatistics&id={}&key={}'.format(video_id, api_key)
    raw = requests.get(api_call).json()
    try:
        combined = {**raw['items'][0]['statistics'],**raw['items'][0]['snippet']}
        fields = ['publishedAt','title','description','tags','viewCount','likeCount','commentCount']
        result = {'video_id': video_id}
        for i in combined.keys():
            if i in fields:
                result[i] = combined[i]
        return result
    except:
        next

video_details = [get_vid_data(video_id) for video_id in videos]
videos_df = pd.DataFrame([i for i in video_details if type(i)==dict])
videos_df.set_index('video_id').to_csv('videos_df.csv')

# %%
def get_sub_comments(parentId, video_id='', token=''): 
    sub_comments = []
    while token or token=='':
        api_call = 'https://youtube.googleapis.com/youtube/v3/comments?part=snippet&parentId={}&key={}'.format(parentId, api_key)
        if token:
            api_call+= '&pageToken={}'.format(token) 
        result = requests.get(api_call).json()
        for item in result['items']:
            record = {"id": item['id'], "videoId": video_id}
            record.update(item['snippet'])
            sub_comments += [record]
        try:
            token= result['nextPageToken']
        except:
            token = False
    return sub_comments

def get_all_comments(video_id, token=''): 
    comments = []
    while token or token=='':
        api_call = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&key={}'.format(video_id, api_key)
        if token:
            api_call+= '&pageToken={}'.format(token) 
        result = requests.get(api_call).json()    
        for item in result['items']:
            record = item['snippet']['topLevelComment']['snippet']
            record['id'] = item['id']
            comments += [record]
            if item['snippet']['totalReplyCount']>0:
                comments+=get_sub_comments(item['id'], video_id)
        try:
            token= result['nextPageToken']
        except:
            token = False
                    
    # build pandas dataframe
    comments_df = pd.DataFrame(comments)
    comments_df['authorId'] = comments_df['authorChannelId'].apply(lambda x: x['value'] if type(x)==dict else '')
    comments_df = comments_df[['videoId','id','parentId','textOriginal','authorId','authorDisplayName','publishedAt','likeCount']]
    return comments_df

# %%
# all_comments=pd.DataFrame()
# videos_df=pd.DataFrame()

# if continuing from where we left off, import from the saved file
all_comments = pd.read_excel('all_comments_df.xlsx')
videos_df = pd.read_csv('videos_df.csv')

errors=[]

# %%
for v in videos_df.sort_values('publishedAt')[100:105]['video_id']:
    all_comments = all_comments[all_comments['videoId']!=v]
    print(v)
    try:
        all_comments = all_comments.append(get_all_comments(v))
    except:
        errors.append(v)
        next        
        
all_comments
# Out:
# c078AVNTjM4
# nz7F2K4-waw
# OjljgkCQv5c
# tPsLcrVlwt4
# aAZac21Y9D8
#                               id      videoId parentId  \
# 0     UgzmjkZjEVFcarVg9wR4AaABAg  BroESGFxWM4      NaN
# 1     Ugx__BHUFiS59gREuel4AaABAg  BroESGFxWM4      NaN
# 2     UgxK-iLVzB-M7R3fylZ4AaABAg  BroESGFxWM4      NaN
# 3     UgwuFIGeaVa2cqf2UX54AaABAg  BroESGFxWM4      NaN
# 4     Ugy77deTOW-4fMiNPn94AaABAg  BroESGFxWM4      NaN
# ...                          ...          ...      ...
# 4593  UgxXkHIz3u0DRcIGrc54AaABAg  aCv29JKmHNY      NaN
# 4594  UgwUIJv_3pHGBcLaV1h4AaABAg  aCv29JKmHNY      NaN
# 4595  UgwWgo7kzWs9OCrI3Vt4AaABAg  aCv29JKmHNY      NaN
# 4596  Ugwx3ObNwTHndXaWsMl4AaABAg  aCv29JKmHNY      NaN
# 4597  UgzUlfNSjunWD_4r4g14AaABAg  aCv29JKmHNY      NaN
#
#                                            textOriginal  \
# 0                                           So cringey.
# 1                                     He's amazing! 😂😂😂
# 2     If only MLKJ knew his words would be used like...
# 3                             DO NOT LIKE THIS COMMENT.
# 4     This guy is proof that anyone with a microphon...
# ...                                                 ...
# 4593                                              Bill!
# 4594                                               cool
# 4595  *if this is blue you watch Netflix*\n👇🏻(I'm gi...
# 4596                                   Фу виндавс гавна
# 4597  *if this is blue you are subscribed to Netflix...
#
#                       authorId              authorDisplayName  \
# 0     UC39z85yXGRZ6MGiwpW0qn6w                          Mat G
# 1     UC0IIqpv4hp_yjbOpMLw2NAw                            Mj.
# 2     UCRiVFpllPbQquw28P33Qe5g                    Rachel Chen
# 3     UC6RbjI1f8owJl78DLK4w2_w                Francis Dourado
# 4     UCsWzFTspp19uPTdydMWOYqQ                          Guang
# ...                        ...                            ...
# 4593  UCggCMFFovyEpAJYjbL3ApTg                     Adam Henry
# 4594  UC3R7rD_g5Dzs-Ga_FQ-M9EQ                   Sovath Zebra
# 4595  UC6rpfofXt4duimS0ame8NSQ  Subscribe to me For no reason
# 4596  UCf_-sYO_dj1JSbfX0qn_E8w                     ПОНЯШКИТОН
# 4597  UC6rpfofXt4duimS0ame8NSQ  Subscribe to me For no reason
#
#                publishedAt  likeCount
# 0     2021-11-12T09:39:56Z          1
# 1     2021-04-01T13:19:59Z          1
# 2     2021-02-10T21:05:06Z          0
# 3     2020-12-22T11:38:53Z          0
# 4     2020-09-25T05:53:11Z          0
# ...                    ...        ...
# 4593  2019-08-29T15:04:31Z          1
# 4594  2019-08-29T15:03:43Z          0
# 4595  2019-08-29T15:03:36Z          7
# 4596  2019-08-29T15:03:07Z          0
# 4597  2019-08-29T15:03:00Z          1
#
# [168774 rows x 8 columns]

# %%
# DEBUGGING

# %%
# video_id='NfpXeLVzJIw'
# token=''
# comments = []
# while token or token=='':
#     api_call = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&key={}'.format(video_id, api_key)
#     if token:
#         api_call+= '&pageToken={}'.format(token) 
#     result = requests.get(api_call).json()
# #         return result
#     for item in result['items']:
#         record = item['snippet']['topLevelComment']['snippet']
#         record['id'] = item['id']
#         comments += [record]
#         if item['snippet']['totalReplyCount']>0:
#             comments+=get_sub_comments(item['id'], video_id)
#     try:
#         token= result['nextPageToken']
#     except:
#         token = False
# #     return comments

# # build pandas dataframe
# comments_df = pd.DataFrame(comments)
# comments_df['authorId'] = comments_df['authorChannelId'].apply(lambda x: x['value'] if type(x)==dict else '')
# comments_df = comments_df[['videoId','id','parentId','textOriginal','authorId','authorDisplayName','publishedAt','likeCount']]
# comments_df

# %%
api_call = 'https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={}&key={}'.format(video_id, api_key)
result = requests.get(api_call).json()  
result
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'F-rf9-lIPSS0zH-u0UYJA9nJNs4',
#  'nextPageToken': 'QURTSl9pMmNEeHZIWW42THBmWGRhM1RqWmVsaG5xQTFuV3RsNVhpeG1WVTNyMzVsYUFtX3lNWUpIYnVUbkFheHRmcnBpT0ZiNEJZLURPSQ==',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'ASUSCdZDbOlyxjAp6_z5FWnUiNg',
#    'id': 'Ugzj-DulT4Hjk4ePrtJ4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'oJrrhqARtDMto7zXDPslXRvxbFY',
#      'id': 'Ugzj-DulT4Hjk4ePrtJ4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'You wondered why people were dressed in suits when you were at Clarke Quay. Both Clarke &amp; Boat Quay are adjacent to the Central Business District where all the financial institutions, local &amp; international, are headquartered.',
#       'textOriginal': 'You wondered why people were dressed in suits when you were at Clarke Quay. Both Clarke & Boat Quay are adjacent to the Central Business District where all the financial institutions, local & international, are headquartered.',
#       'authorDisplayName': 'Li Teo',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9TymKcFvOuuE7S2BQXjG67tkrKPWNaPBk2Aw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCFmRvQSRDO1T4dfV6UVwJYA',
#       'authorChannelId': {'value': 'UCFmRvQSRDO1T4dfV6UVwJYA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-07T04:14:38Z',
#       'updatedAt': '2022-09-07T04:14:38Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xhPJRvVfXpI_vnuQPNKJf2SZ2uI',
#    'id': 'UgyOyZs7j1ua7545Jcp4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JFI-0IUqae6OtBh_7T8ttSEmTOI',
#      'id': 'UgyOyZs7j1ua7545Jcp4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'You should try the hum jin pang here aka fried dough. They are the best in Singapore.',
#       'textOriginal': 'You should try the hum jin pang here aka fried dough. They are the best in Singapore.',
#       'authorDisplayName': 'Ng KOK WEI',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9e73vsQRvHU12urcqyHgxBnQ3V7sI5hn3KjCbJ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC59IiFd2OWWc_XJjWSmxPHg',
#       'authorChannelId': {'value': 'UC59IiFd2OWWc_XJjWSmxPHg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-05T04:31:09Z',
#       'updatedAt': '2022-09-05T04:31:09Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2OFnuGaerSP8h2XI3Ca2I0FJIEU',
#    'id': 'UgzvY8kiUESulZmk-vV4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NOAOKjKroBpYkmLEk5hwHL5qw6A',
#      'id': 'UgzvY8kiUESulZmk-vV4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Welcome to Singapore!',
#       'textOriginal': 'Welcome to Singapore!',
#       'authorDisplayName': 'Ng KOK WEI',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9e73vsQRvHU12urcqyHgxBnQ3V7sI5hn3KjCbJ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC59IiFd2OWWc_XJjWSmxPHg',
#       'authorChannelId': {'value': 'UC59IiFd2OWWc_XJjWSmxPHg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-05T04:24:23Z',
#       'updatedAt': '2022-09-05T04:24:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'fb4ooGpa-yNxrdWS091ztXdOd94',
#    'id': 'UgzQ8ashTGvDGrM9yUR4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'vodlkqWN8IgZweeXc6kmiPD-CvQ',
#      'id': 'UgzQ8ashTGvDGrM9yUR4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Good that you could video in the temple.  Some other YouTubers said that they couldn&#39;t video in it.',
#       'textOriginal': "Good that you could video in the temple.  Some other YouTubers said that they couldn't video in it.",
#       'authorDisplayName': 'Sean',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-3dP07zd2VtROTWg5AD0SVLqfH9Zfx2vPWmsJLdAI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCrdSagFhN8dSHbhTocftu2g',
#       'authorChannelId': {'value': 'UCrdSagFhN8dSHbhTocftu2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-04T22:15:56Z',
#       'updatedAt': '2022-09-04T22:15:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'SAWlShcYcsjFiptEsivtqxYYj4o',
#    'id': 'Ugx-_CzOYBVLBNa9P3B4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'zf8qeF59hwLqbLfUwKABjimgx24',
#      'id': 'Ugx-_CzOYBVLBNa9P3B4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=oYJGWcZ4lVQ&amp;t=25m04s">25:04</a> that dessert if you called it by local name, is called Dao Suan, based on a Chinese dialect',
#       'textOriginal': '25:04 that dessert if you called it by local name, is called Dao Suan, based on a Chinese dialect',
#       'authorDisplayName': 'Sean',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-3dP07zd2VtROTWg5AD0SVLqfH9Zfx2vPWmsJLdAI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCrdSagFhN8dSHbhTocftu2g',
#       'authorChannelId': {'value': 'UCrdSagFhN8dSHbhTocftu2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-04T22:12:57Z',
#       'updatedAt': '2022-09-04T22:12:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0lujv5LWjCFLix1-L8o4oGTNP7I',
#    'id': 'UgxwCaS_8b4aBBgFh814AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MjX7WDS_IUS743bBGRojNMY9goY',
#      'id': 'UgxwCaS_8b4aBBgFh814AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'I like how the lady broke out in a sweet smile whenever she enjoys the food and beverages',
#       'textOriginal': 'I like how the lady broke out in a sweet smile whenever she enjoys the food and beverages',
#       'authorDisplayName': 'Sean',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-3dP07zd2VtROTWg5AD0SVLqfH9Zfx2vPWmsJLdAI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCrdSagFhN8dSHbhTocftu2g',
#       'authorChannelId': {'value': 'UCrdSagFhN8dSHbhTocftu2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-04T22:07:56Z',
#       'updatedAt': '2022-09-04T22:07:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'm7cet62sW1k3cxvy6Njt_-2PMO4',
#    'id': 'Ugz7pcl43LAEVCHsQy94AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '-rp29Vw7mW7PwHU4FFViU8TaqrA',
#      'id': 'Ugz7pcl43LAEVCHsQy94AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Your US accent is so good.',
#       'textOriginal': 'Your US accent is so good.',
#       'authorDisplayName': 'Sean',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-3dP07zd2VtROTWg5AD0SVLqfH9Zfx2vPWmsJLdAI=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCrdSagFhN8dSHbhTocftu2g',
#       'authorChannelId': {'value': 'UCrdSagFhN8dSHbhTocftu2g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-04T21:53:33Z',
#       'updatedAt': '2022-09-04T21:53:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'jc-HKZsE8HLIPCUA3HRoxGKGKHc',
#    'id': 'UgwYHjNDeJOM2nOLruh4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'f-OTIsD7ju6Zhll9LSplxCsEhuo',
#      'id': 'UgwYHjNDeJOM2nOLruh4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Great perspective👍',
#       'textOriginal': 'Great perspective👍',
#       'authorDisplayName': 'Andrew WLT',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu--t11pL06WKWK6l1P8LuS4tfKH79oUYahP5JoR=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCecc5ZUKubAVb9EXhoshNfQ',
#       'authorChannelId': {'value': 'UCecc5ZUKubAVb9EXhoshNfQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-09-04T08:22:50Z',
#       'updatedAt': '2022-09-04T08:22:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OCyW0zUTLdh6ASp4JJy4m0YPFck',
#    'id': 'UgyZpIFwq5CqkqPUnLR4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'RJF4QcXAw0GtjqiEugiGaHnWCWM',
#      'id': 'UgyZpIFwq5CqkqPUnLR4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Singapore is nice but, most incredible country in the world. if you did not visited any other country you might be right.',
#       'textOriginal': 'Singapore is nice but, most incredible country in the world. if you did not visited any other country you might be right.',
#       'authorDisplayName': 'Mustafa Tokgoz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu9yvCe00OWc6k1Z-c5SECjM_0SHXmS7w1ecRA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCsoHPq4XMPuWEi8fJI0ZQfQ',
#       'authorChannelId': {'value': 'UCsoHPq4XMPuWEi8fJI0ZQfQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-09-01T17:45:57Z',
#       'updatedAt': '2022-09-01T17:45:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'YouvGtXma9G-BNjvwOWprwMD6tQ',
#    'id': 'UgwiQGCbqE7f6rIzoUR4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'R5ju_9MZhUtVybAtkG-lsktQKsM',
#      'id': 'UgwiQGCbqE7f6rIzoUR4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Doin&#39; a great job.  Interesting perspective.  I have been to some of the places you have on your video.  I think it&#39;s time for another trip.',
#       'textOriginal': "Doin' a great job.  Interesting perspective.  I have been to some of the places you have on your video.  I think it's time for another trip.",
#       'authorDisplayName': 'Nishan D',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_wYO5n5r12eXeuXfYJBRmxVVnoYSz5VasUXq5J=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCcEnGXhj7ydvIJilMu-rgxw',
#       'authorChannelId': {'value': 'UCcEnGXhj7ydvIJilMu-rgxw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-31T13:29:34Z',
#       'updatedAt': '2022-08-31T13:29:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'kiDteHekUuif6cNpmBpdbv_bBp0',
#    'id': 'UgzfFie0Qbv8u9SemlF4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B-ve09sHMWaqollO4U68QpBPo0g',
#      'id': 'UgzfFie0Qbv8u9SemlF4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'lets follow your south asia journey, love the citilighting in singapore and dont forget the culinarry also something else that you have to taste,great job my friend',
#       'textOriginal': 'lets follow your south asia journey, love the citilighting in singapore and dont forget the culinarry also something else that you have to taste,great job my friend',
#       'authorDisplayName': 'Grandma uti',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Pke-btXG0QnmPjStVqryaqRzoAQlh1qEbcC9nYf7Q6oTGBuzvJW--rtUHe-JXlaw9T8Sh_U_gQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCpjPlmgmJtqrNJchqsZhfhQ',
#       'authorChannelId': {'value': 'UCpjPlmgmJtqrNJchqsZhfhQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-29T09:43:18Z',
#       'updatedAt': '2022-08-29T09:43:18Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'f2FROLMRML1zdjYa5bezZav5MBY',
#    'id': 'UgzFa6fe8uhR0lAHI1F4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'GLicAUiQ_fQivdZIh1aN47oXG8M',
#      'id': 'UgzFa6fe8uhR0lAHI1F4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Singapore is a very expensive place n it&#39;s very boring. I grew up here n I know Singapore best. The good thing about Singapore is security n very low crime rate, that&#39;s about it!',
#       'textOriginal': "Singapore is a very expensive place n it's very boring. I grew up here n I know Singapore best. The good thing about Singapore is security n very low crime rate, that's about it!",
#       'authorDisplayName': 'Fiat 500',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu95e1QoWZ2i0h4e5mMMn5tR6DP5-vwKPTF97wL22g=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCOkSpbyGwBj9pFDCEMNf5JQ',
#       'authorChannelId': {'value': 'UCOkSpbyGwBj9pFDCEMNf5JQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-27T19:44:10Z',
#       'updatedAt': '2022-08-28T15:32:17Z'}},
#     'canReply': True,
#     'totalReplyCount': 11,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hrM2mvjLNtxGZSAypgTGTgRETUw',
#    'id': 'UgymzF6dDJJ9Ik-ciYN4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'jeN9NvGaWVROqcXtOHZ_Jd-BsQQ',
#      'id': 'UgymzF6dDJJ9Ik-ciYN4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'in Kuala Lumpur Malaysia.',
#       'textOriginal': 'in Kuala Lumpur Malaysia.',
#       'authorDisplayName': 'Chiang Ea',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/cqCPCrm2yjx98mwX3JQDPf3qCSyk1jLoWxp5QKrLPwPqngazD7NN6PtCrXjbHLGpYdANljb2PQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyuaENMSeU7IGAbuF0yYuig',
#       'authorChannelId': {'value': 'UCyuaENMSeU7IGAbuF0yYuig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2022-08-27T11:42:44Z',
#       'updatedAt': '2022-08-27T11:42:44Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4woYOWjfSZVtl2GVq54f7WlWaSY',
#    'id': 'UgyeHPqeZb1acDo8Lcl4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'F7xo8ZvDH7E1rRdkO3rLzbg3qR0',
#      'id': 'UgyeHPqeZb1acDo8Lcl4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'You can get the same standard of living and more varieties of foods with 1/3 of the cost that you are spending in Sinapore !',
#       'textOriginal': 'You can get the same standard of living and more varieties of foods with 1/3 of the cost that you are spending in Sinapore !',
#       'authorDisplayName': 'Chiang Ea',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/cqCPCrm2yjx98mwX3JQDPf3qCSyk1jLoWxp5QKrLPwPqngazD7NN6PtCrXjbHLGpYdANljb2PQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCyuaENMSeU7IGAbuF0yYuig',
#       'authorChannelId': {'value': 'UCyuaENMSeU7IGAbuF0yYuig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-27T11:41:45Z',
#       'updatedAt': '2022-08-27T11:41:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'FkjV2jgIsUU5qBXSOnYlFqmvBHU',
#    'id': 'UgyqGbXCmLKQvQ7uq3l4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0q21ACCfAxKpw9BmcLlX4sOwCyk',
#      'id': 'UgyqGbXCmLKQvQ7uq3l4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Hey, we’re from Texas too and congrats on your first video. We ate the same spot in the Maxwell food Centre this past July as well. Wishing you guys the best on the rest of your journey. Check out our channel if you have the chance.',
#       'textOriginal': 'Hey, we’re from Texas too and congrats on your first video. We ate the same spot in the Maxwell food Centre this past July as well. Wishing you guys the best on the rest of your journey. Check out our channel if you have the chance.',
#       'authorDisplayName': 'Indo Chimps',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/WD3gNjU1dkUFESgUhhcz2EQxDZlQiXj6J0iqFWt4lVhnXGO1xNppquTglyrYLObwFyQweghT=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4fE1qmvHgO0rfjs-H2AMaQ',
#       'authorChannelId': {'value': 'UC4fE1qmvHgO0rfjs-H2AMaQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2022-08-27T01:13:25Z',
#       'updatedAt': '2022-08-27T01:13:25Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'cWadJ8kSYBoGpG2nBwM9XdsNp4A',
#    'id': 'UgySx_B6MUT4lX9wlZN4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AbdqO8VtAZbojAPabq-pdk0sXLs',
#      'id': 'UgySx_B6MUT4lX9wlZN4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'In South East Asia, we usually use the spoon to scoop the rice. Most Westerners use the fork which is not very efficient 🙂',
#       'textOriginal': 'In South East Asia, we usually use the spoon to scoop the rice. Most Westerners use the fork which is not very efficient 🙂',
#       'authorDisplayName': 'Steve Kiang',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu8Yjt_aD-QuVClvaYKnyV_NyV5IBAQG-Z1zHPqfrpA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCVSYvgfPexgJ8Yto19yOeig',
#       'authorChannelId': {'value': 'UCVSYvgfPexgJ8Yto19yOeig'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2022-08-26T06:09:35Z',
#       'updatedAt': '2022-08-26T06:09:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'hEP4jmUcROhsYenBYOKAX_iWapI',
#    'id': 'UgyZ_xQFt6PRr073ULB4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0vw9NVImWGs_urdtQqH74HvMkyo',
#      'id': 'UgyZ_xQFt6PRr073ULB4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'living in singapore!!!!!?????? you will be bored after 3 years in the positive way of thinking.....then you will be back to sri lanka then perhaps back to LA????',
#       'textOriginal': 'living in singapore!!!!!?????? you will be bored after 3 years in the positive way of thinking.....then you will be back to sri lanka then perhaps back to LA????',
#       'authorDisplayName': 'or jan',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-3k68qJqjjkOAnF8D721SM3KOgOrloGX7APdSxnJIfQtmLaipg9993bo-ohkpM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCf9YT9EUIhSnL9gaU93H7vg',
#       'authorChannelId': {'value': 'UCf9YT9EUIhSnL9gaU93H7vg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2022-08-24T22:17:22Z',
#       'updatedAt': '2022-08-24T22:17:22Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'COrUsNCZVuhvXbxzeYjrX7_yqHY',
#    'id': 'UgxlzFtwnoFZsEfk8Sx4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'U5lZd9DgPVQK-5pwauepN6pABQ8',
#      'id': 'UgxlzFtwnoFZsEfk8Sx4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Awesome first video :) ! We had a transit in Singapore, wish we had time to explore their haha!',
#       'textOriginal': 'Awesome first video :) ! We had a transit in Singapore, wish we had time to explore their haha!',
#       'authorDisplayName': 'Kreate Travels',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/5_79WN-3QGr0swj5WQW634ZRsAd7ItGciyTU18H2r4NjMXhSAkkVXUP_RdPuMbcepOcP0HDW=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCribxbTbn--EYd6t8NLcctg',
#       'authorChannelId': {'value': 'UCribxbTbn--EYd6t8NLcctg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2022-08-23T09:31:13Z',
#       'updatedAt': '2022-08-23T09:31:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'CpAFhc2hZP-wpDqr3lvRG9b3ojE',
#    'id': 'UgxsHK-jEc-zRq63McV4AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UwUCvZKsmwN2XSVVrfPQiUDpVGY',
#      'id': 'UgxsHK-jEc-zRq63McV4AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'Why are you guys eating  chicken rice with a fork?  You should be eating it using a spoon and a fork. Not necessarily every chicken rice stall must have a long queue. Most of the stalls in Singapore equally have tasty chicken rice, not only  at Tian Tian. 🇸🇬',
#       'textOriginal': 'Why are you guys eating  chicken rice with a fork?  You should be eating it using a spoon and a fork. Not necessarily every chicken rice stall must have a long queue. Most of the stalls in Singapore equally have tasty chicken rice, not only  at Tian Tian. 🇸🇬',
#       'authorDisplayName': 'Vani Vani',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu-PWwKEYiK_HG3ArHRy7DwFmPgr3sJT7ia4_A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UCmFcsGwUhBPpcXocVIjAbyw',
#       'authorChannelId': {'value': 'UCmFcsGwUhBPpcXocVIjAbyw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2022-08-20T14:54:12Z',
#       'updatedAt': '2022-08-20T15:03:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'tTSIQ2Xk_7tQzxgrWwNs3a7sshI',
#    'id': 'UgwHb2C0HiEhM1uDLd94AaABAg',
#    'snippet': {'videoId': 'oYJGWcZ4lVQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'nm-aXUwbXrzqKxGkJH-7SlgQhsc',
#      'id': 'UgwHb2C0HiEhM1uDLd94AaABAg',
#      'snippet': {'videoId': 'oYJGWcZ4lVQ',
#       'textDisplay': 'It’s Mung bean ( green bean without skin)',
#       'textOriginal': 'It’s Mung bean ( green bean without skin)',
#       'authorDisplayName': 'Felice Oei',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AMLnZu_L8FBMsHgw-Q5mzPmHGBiY31urixs3fdrWknq_dtDHElbNjR9nOTOxm9L5QFZG=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/channel/UC4EqDy5GMWnxe1WJSlVij5Q',
#       'authorChannelId': {'value': 'UC4EqDy5GMWnxe1WJSlVij5Q'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2022-08-19T00:28:31Z',
#       'updatedAt': '2022-08-19T00:28:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}}]}
